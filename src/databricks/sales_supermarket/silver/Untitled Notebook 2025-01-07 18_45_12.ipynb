# %%
# %run ../../lib/utils

# %%
# %run ../../lib/ingestors

# %%
catalog = 'silver'

dbutils.widgets.text('schema_name', '')
dbutils.widgets.text('table_name', '')
dbutils.widgets.text('write_mode', '')

schema_name = dbutils.widgets.get('schema_name')
table_name = dbutils.widgets.get('table_name')
write_mode = dbutils.widgets.get('write_mode')

# %%
df = spark.table('bronze.postgres.dim_customers')

# %%
source_path =  f'/Volumes/raw/{schema_name}/sales_db/{table_name}'
checkpoint_path = f'/Volumes/raw/{schema_name}/sales_db/{table_name}_checkpoint'
data_format = 'delta'

# %%
df.write.mode('overwrite').saveAsTable('silver.postgres.dim_customers')
